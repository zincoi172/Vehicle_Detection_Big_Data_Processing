# %%
from kafka import KafkaConsumer
import json
import psycopg2
from datetime import datetime

# Kafka Consumer setup
consumer = KafkaConsumer(
    'parking-spot-status',
    bootstrap_servers='localhost:9092',
    value_deserializer=lambda m: json.loads(m.decode('utf-8'))
)

# PostgreSQL connection
conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='mysecretpassword'
)
cursor = conn.cursor()

print("Kafka → PostgreSQL 3-min Snapshot Consumer started...")

last_written_minute = None  # Used to prevent duplicate writes within the same 3-min block

for msg in consumer:
    data = msg.value
    now = datetime.now()
    current_minute = now.minute

    # Only insert once every 3-minute boundary (e.g., 0, 3, 6, 9, ...)
    if current_minute % 3 == 0 and current_minute != last_written_minute:
        last_written_minute = current_minute

        for spot in data['spots']:
            spot_id = spot['id']
            status = spot['status']

            cursor.execute("""
                INSERT INTO parking_status (spot_id, status, timestamp)
                VALUES (%s, %s, %s)
            """, (spot_id, status, now))
            conn.commit()

            print(f"[3-min Snapshot] Spot {spot_id} = {status} at {now}")
# Out:
# Kafka → PostgreSQL 3-min Snapshot Consumer started...
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:03:42.929179
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:03:42.929179
# [3-min Snapshot] Spot 3 = Occupied at 2025-05-05 14:03:42.929179
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:06:04.825976
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:06:04.825976
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:06:04.825976
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:09:03.736813
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:09:03.736813
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:09:03.736813
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:12:00.716669
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:12:00.716669
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:12:00.716669
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:15:02.893219
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:15:02.893219
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:15:02.893219
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:18:04.963675
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:18:04.963675
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:18:04.963675
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:21:02.090229
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:21:02.090229
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:21:02.090229
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:24:04.826148
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:24:04.826148
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:24:04.826148
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:27:01.638404
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:27:01.638404
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:27:01.638404
# [3-min Snapshot] Spot 1 = Occupied at 2025-05-05 14:30:03.577049
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:30:03.577049
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:30:03.577049
# [3-min Snapshot] Spot 1 = Empty at 2025-05-05 14:33:00.610116
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:33:00.610116
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:33:00.610116
# [3-min Snapshot] Spot 1 = Empty at 2025-05-05 14:36:02.465060
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:36:02.465060
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:36:02.465060
# [3-min Snapshot] Spot 1 = Empty at 2025-05-05 14:39:01.176933
# [3-min Snapshot] Spot 2 = Occupied at 2025-05-05 14:39:01.176933
# [3-min Snapshot] Spot 3 = Empty at 2025-05-05 14:39:01.176933
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 27
#      23 print("Kafka → PostgreSQL 3-min Snapshot Consumer started...")
#      25 last_written_minute = None  # Used to prevent duplicate writes within the same 3-min block
# ---> 27 for msg in consumer:
#      28     data = msg.value
#      29     now = datetime.now()
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1190, in KafkaConsumer.__next__(self)
#    1188     self._iterator = self._message_generator_v2()
#    1189 try:
# -> 1190     return next(self._iterator)
#    1191 except StopIteration:
#    1192     self._iterator = None
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:1162, in KafkaConsumer._message_generator_v2(self)
#    1160 def _message_generator_v2(self):
#    1161     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1162     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1163     for tp, records in six.iteritems(record_map):
#    1164         # Generators are stateful, and it is possible that the tp / records
#    1165         # here may become stale during iteration -- i.e., we seek to a
#    1166         # different offset, pause consumption, or lose assignment.
#    1167         for record in records:
#    1168             # is_fetchable(tp) should handle assignment changes and offset
#    1169             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1170             # outer function destroying the existing iterator/generator
#    1171             # via self._iterator = None
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     683 while not self._closed:
# --> 684     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\consumer\group.py:730, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     727 if not has_all_fetch_positions:
#     728     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 730 self._client.poll(timeout_ms=poll_timeout_ms)
#     731 # after the long poll, we should check whether the group needs to rebalance
#     732 # prior to returning data so that the group can stabilize faster
#     733 if self._coordinator.need_rejoin():
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:689, in KafkaClient.poll(self, timeout_ms, future)
#     682         timeout = min(
#     683             user_timeout_ms,
#     684             metadata_timeout_ms,
#     685             idle_connection_timeout_ms,
#     686             request_timeout_ms)
#     687         timeout = max(0, timeout)  # avoid negative timeouts
# --> 689     self._poll(timeout / 1000)
#     691 # called without the lock to avoid deadlock potential
#     692 # if handlers need to acquire locks
#     693 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\site-packages\kafka\client_async.py:732, in KafkaClient._poll(self, timeout)
#     729 self._register_send_sockets()
#     731 start_select = time.time()
# --> 732 ready = self._selector.select(timeout)
#     733 end_select = time.time()
#     734 if self._sensors:
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\jj111\AppData\Local\Programs\Python\Python310\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
