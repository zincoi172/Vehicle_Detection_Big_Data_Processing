# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 1) Check classes in our first trained model using Coco Dataset

# %%
from ultralytics import YOLO
# Load our first trained model
model = YOLO('/Users/daivo/Desktop/SJSU 2024/Spring 2025/DATA 228/228 Project/result_first_train/first_train.pt')

print("Model class names:")
for cls_id, name in model.names.items():
    print(f"{cls_id}: {name}")
# Out:
# Model class names:
# 0: person
# 1: bicycle
# 2: car
# 3: motorcycle
# 4: airplane
# 5: bus
# 6: train
# 7: truck
# 8: boat
# 9: traffic light
# 10: fire hydrant
# 11: stop sign
# 12: parking meter
# 13: bench
# 14: bird
# 15: cat
# 16: dog
# 17: horse
# 18: sheep
# 19: cow
# 20: elephant
# 21: bear
# 22: zebra
# 23: giraffe
# 24: backpack
# 25: umbrella
# 26: handbag
# 27: tie
# 28: suitcase
# 29: frisbee
# 30: skis
# 31: snowboard
# 32: sports ball
# 33: kite
# 34: baseball bat
# 35: baseball glove
# 36: skateboard
# 37: surfboard
# 38: tennis racket
# 39: bottle
# 40: wine glass
# 41: cup
# 42: fork
# 43: knife
# 44: spoon
# 45: bowl
# 46: banana
# 47: apple
# 48: sandwich
# 49: orange
# 50: broccoli
# 51: carrot
# 52: hot dog
# 53: pizza
# 54: donut
# 55: cake
# 56: chair
# 57: couch
# 58: potted plant
# 59: bed
# 60: dining table
# 61: toilet
# 62: TV
# 63: laptop
# 64: mouse
# 65: remote
# 66: keyboard
# 67: cell phone
# 68: microwave
# 69: oven
# 70: toaster
# 71: sink
# ...

# %% [markdown]
# # 2) Check classes for our last trained model using directly MIO Dataset

# %%
from ultralytics import YOLO

# Load your final model
model = YOLO('/Users/daivo/Desktop/SJSU 2024/Spring 2025/DATA 228/228 Project/result_final_best/final_best.pt')
print("Model class names:")
for cls_id, name in model.names.items():
    print(f"{cls_id}: {name}")
# Out:
# Model class names:
# 0: Articulated truck
# 1: Bicycle
# 2: Bus
# 3: Car
# 4: Motorcycle
# 5: Motorized vehicle
# 6: Non-motorized vehicle
# 7: Pedestrian
# 8: Pickup truck
# 9: Single unit truck
# 10: Work van

# %% [markdown]
# # 3) Check classes for online source trained model to compare with our result

# %%
from ultralytics import YOLO
# Load your final model
model = YOLO('/Users/daivo/Desktop/SJSU 2024/Spring 2025/DATA 228/228 Project/result_yolov8n/yolov8n.pt')
print(" Model class names:")
for cls_id, name in model.names.items():
    print(f"{cls_id}: {name}")
# Out:
#  Model class names:
# 0: person
# 1: bicycle
# 2: car
# 3: motorcycle
# 4: airplane
# 5: bus
# 6: train
# 7: truck
# 8: boat
# 9: traffic light
# 10: fire hydrant
# 11: stop sign
# 12: parking meter
# 13: bench
# 14: bird
# 15: cat
# 16: dog
# 17: horse
# 18: sheep
# 19: cow
# 20: elephant
# 21: bear
# 22: zebra
# 23: giraffe
# 24: backpack
# 25: umbrella
# 26: handbag
# 27: tie
# 28: suitcase
# 29: frisbee
# 30: skis
# 31: snowboard
# 32: sports ball
# 33: kite
# 34: baseball bat
# 35: baseball glove
# 36: skateboard
# 37: surfboard
# 38: tennis racket
# 39: bottle
# 40: wine glass
# 41: cup
# 42: fork
# 43: knife
# 44: spoon
# 45: bowl
# 46: banana
# 47: apple
# 48: sandwich
# 49: orange
# 50: broccoli
# 51: carrot
# 52: hot dog
# 53: pizza
# 54: donut
# 55: cake
# 56: chair
# 57: couch
# 58: potted plant
# 59: bed
# 60: dining table
# 61: toilet
# 62: tv
# 63: laptop
# 64: mouse
# 65: remote
# 66: keyboard
# 67: cell phone
# 68: microwave
# 69: oven
# 70: toaster
# 71: sink
# ...
